# %% [markdown]
# Real Estate Crime Statistics Exploratory Data Analysis (EDA)

# %%
# Imports and Load Cleaned Data
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

plt.style.use ("ggplot")

crime_df = pd.read_csv('/Users/amirkalam/Desktop/Rockborne/Python Module/Jupyter Note/cleaned_crime_data.csv')
